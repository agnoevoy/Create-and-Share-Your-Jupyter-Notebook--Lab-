# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * List popular languages for Data Science
# * Show some of the commonly ued libraries used by Data Scientists
# * List open source development environment used in data science
# * Provide few examples of evaluating arithmetic expression in Python

# %% [markdown]
# **Some of the popular languages that Data Scientists use are:**
# * Python
# * R
# * SQL
# * Julia

# %% [markdown]
# **Some of the commonly used libraries used by Data Scientists include:**
# * For Python :
#     * Scientifics Computing
#         * Pandas (data structure and tools)
#         * NumPy (Arrays & matrices)
#     * Visualisation
#         * Matplotlib (plots & graphs)
#         * Seaborn (plots, heat maps, time series, violin plots)
#     * Machine Learning (ML) and Deep Learning (DL)
#         * Scikit-learn (ML)
#         * Keras (DL)
#         * TenserFlow (DL)
#         * PyTorch (DL)
# * R libraries
#     * ggplot2 for data visualisation
#     * libraries to interface with Keras and TenserFlow

# %% [markdown]
# **Development environment open source tools used in data science**
#
# |№|Data Science Tools|
# |-|------------------|
# |1|Jupyter Notebook / JupyterLab|
# |2|RStudio|
# |3|Apache Zeppelin|
# |4|Spyder|
# |5|VS Code|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
Result = 3*4+5
print("The result is:", Result)
# Out:
# The result is: 17

# %%
# This will convert 200 minutes to hours by diving by 60
Result = 200/60
print("200 minutes is equal to", format(Result, ".2f"), "hours")
# Out:
# 200 minutes is equal to 3.33 hours

# %% [markdown]
# ## Author
# Alexey Gnoevoy

# %% [markdown]
# Copyright ©2025 IBM Corporation. All rights reserved.
